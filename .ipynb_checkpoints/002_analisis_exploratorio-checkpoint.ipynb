# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
original_data = pd.read_csv('./Data_clean')
original_data.head(5)
# Out:
#    Unnamed: 0  N_factura  ID_Cliente            País  Cantidad   Monto  \
# 0           0     548370     15528.0  United Kingdom       123  229.33
# 1           1     575767     17348.0  United Kingdom       163  209.73
# 2           3     549106     17045.0  United Kingdom         1   39.95
# 3           4     573112     16416.0  United Kingdom       357  344.83
# 4           5     576630     13816.0         Germany        91  199.98
#
#                  Fecha Continente        Mes  Dia   Año  Periodo  Out_kingdom  \
# 0  2021-03-30 16:14:00     Europa      Marzo   30  2021  2021 03            0
# 1  2021-11-11 11:11:00     Europa  Noviembre   11  2021  2021 11            0
# 2  2021-04-06 12:08:00     Europa      Abril    6  2021  2021 04            0
# 3  2021-10-27 15:33:00     Europa    Octubre   27  2021  2021 10            0
# 4  2021-11-16 08:38:00     Europa  Noviembre   16  2021  2021 11            1
#
#   Volumen_cantidad
# 0      100<=x<=300
# 1      100<=x<=300
# 2            x<100
# 3      300<=x<=600
# 4            x<100

# %%
data = original_data.copy()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18562 entries, 0 to 18561
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        18562 non-null  int64
#  1   N_factura         18562 non-null  int64
#  2   ID_Cliente        18562 non-null  float64
#  3   País              18562 non-null  object
#  4   Cantidad          18562 non-null  int64
#  5   Monto             18562 non-null  float64
#  6   Fecha             18562 non-null  object
#  7   Continente        18554 non-null  object
#  8   Mes               18562 non-null  object
#  9   Dia               18562 non-null  int64
#  10  Año               18562 non-null  int64
#  11  Periodo           18562 non-null  object
#  12  Out_kingdom       18562 non-null  int64
#  13  Volumen_cantidad  18562 non-null  object
# dtypes: float64(2), int64(6), object(6)
# memory usage: 2.0+ MB

# %% [markdown]
# ## 1) ¿Cuanto se vende en promedio por mes?
#
# - **Esto lo puedo mejorar creando diccionarios donde el la llave sea el periodo y el valor el  promedio**

# %%
# creare un array que guarde los periodos de venta    
periodos = data['Periodo'].value_counts().reset_index(name='cantidad')
lista_periodos = periodos['index']

# la funcion calcula el promedio vendido dependiendo del periodo mediante una logica
def calcular_promedio_periodo(lista):

    promedio_periodo = []
    
    for i in lista_periodos:
        # este array es una pequeña tabla donde solo tienen los datos que corresponden con i
        array = lista[lista['Periodo'] == i]
        valor_promedio_periodo = array['Monto'].mean()
        
        promedio_periodo.append(valor_promedio_periodo)
        
    return(promedio_periodo)

promedio_periodos = calcular_promedio_periodo(data)

# organizaremos en nivel ascendente los periodos
indices_periodos = np.argsort(lista_periodos)
# crearemos lista que sigan este orden para no perder la relacion
periodos = [lista_periodos[i] for i in indices_periodos]
promedio = [promedio_periodos[i] for i in indices_periodos]

# %%
fig, ax = plt.subplots( figsize=(7,7))
fig.subplots_adjust(hspace=0.5)


sns.barplot(x=periodos, y=promedio)
ax.set_title('calculo')
ax.tick_params(axis='x', rotation=30);
#ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
#plt.show()

# %% [markdown]
# ## 1.1) Cuanto se vende en promedio por mes FUERA de reino unido

# %%
# separo un dataframe con ventas FUERA de reino unido
Out_kingdom = data[data['Out_kingdom'] == 1]

# creo una lista de los periodos de venta
periodos = Out_kingdom.Periodo.value_counts().reset_index(name='cantidad')
lista_periodos = periodos['index']

# funcion que calcula el promedio dependiendo de el periodo 
def calcular_promedio(lista):
    promedio_periodo = []
    
    for i in lista_periodos:
        minidf = lista[lista['Periodo'] == i]
        promedio = minidf.Monto.mean()
        promedio_periodo.append(promedio)
        
    return(promedio_periodo)

lista_promedio = calcular_promedio(Out_kingdom)

# organizare el periodo en orden
indices_periodo = np.argsort(lista_periodos)
# organizo las lista en orden ascendente de los periodos
periodos = [lista_periodos[i] for i in indices_periodo]
promedio = [lista_promedio[i] for i in indices_periodo]

# %%
fig, ax = plt.subplots( figsize=(7,7))
fig.subplots_adjust(hspace=0.5)

sns.barplot(x=periodos, y=promedio)
ax.set_title('calculo')
ax.tick_params(axis='x', rotation=30);

# %% [markdown]
# ## 1.2) Cuanto se vende en promedio por mes DENTRO de reino unido

# %%
# separo un dataframe con ventas DENTRO de reino unido
Out_kingdom = data[data['Out_kingdom'] == 0]

# creo una lista de los periodos de venta
periodos = Out_kingdom.Periodo.value_counts().reset_index(name='cantidad')
lista_periodos = periodos['index']

# funcion que calcula el promedio dependiendo de el periodo 
def calcular_promedio(lista):
    promedio_periodo = []
    
    for i in lista_periodos:
        minidf = lista[lista['Periodo'] == i]
        promedio = minidf.Monto.mean()
        promedio_periodo.append(promedio)
        
    return(promedio_periodo)

lista_promedio = calcular_promedio(Out_kingdom)

# organizare el periodo en orden
indices_periodo = np.argsort(lista_periodos)
# organizo las lista en orden ascendente de los periodos
periodos = [lista_periodos[i] for i in indices_periodo]
promedio = [lista_promedio[i] for i in indices_periodo]

# %%
fig, ax = plt.subplots( figsize=(7,7))
fig.subplots_adjust(hspace=0.5)

sns.barplot(x=periodos, y=promedio)
ax.set_title('calculo')
ax.tick_params(axis='x', rotation=30);
#ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
#plt.show()

# %% [markdown]
# # mediana de las ventas en el periodo seleccionado

# %%
from statistics import median
# creare un array que guarde los periodos de venta    
periodos = data['Periodo'].value_counts().reset_index(name='cantidad')
lista_periodos = periodos['index']

# la funcion calcula el promedio vendido dependiendo del periodo mediante una logica
def calcular_mediana_periodo(lista):

    mediana_periodo = []
    
    for i in lista_periodos:
        # este array es una pequeña tabla donde solo tienen los datos que corresponden con i
        array = lista[lista['Periodo'] == i]
        valor_mediana_periodo = median(array['Monto'])
        
        mediana_periodo.append(valor_mediana_periodo)
        
    return(mediana_periodo)

mediana_periodos = calcular_mediana_periodo(data)

# organizaremos en nivel ascendente los periodos
indices_periodos = np.argsort(lista_periodos)
# crearemos lista que sigan este orden para no perder la relacion
periodos = [lista_periodos[i] for i in indices_periodos]
mediana = [mediana_periodos[i] for i in indices_periodos]

# %%
fig, ax = plt.subplots(figsize=(7,7))
fig.subplots_adjust(hspace=0.5)

sns.barplot(x=periodos, y=mediana)
ax.tick_params(axis='x', rotation=30);

# %% [markdown]
# ## meidana de las ventas DENTRO de reino unido por peridos

# %%
from statistics import median

# separo un dataframe con ventas DENTRO de reino unido
Out_kingdom = data[data['Out_kingdom'] == 0]

# creo una lista de los periodos de venta
periodos = Out_kingdom.Periodo.value_counts().reset_index(name='cantidad')
lista_periodos = periodos['index']

# funcion que calcula el promedio dependiendo de el periodo 
def calcular_mediana(lista):
    mediana_periodo = []
    
    for i in lista_periodos:
        minidf = lista[lista['Periodo'] == i]
        mediana = median(minidf.Monto)
        mediana_periodo.append(mediana)
        
    return(mediana_periodo)

lista_mediana = calcular_mediana(Out_kingdom)

# organizare el periodo en orden
indices_periodo = np.argsort(lista_periodos)
# organizo las lista en orden ascendente de los periodos
periodos = [lista_periodos[i] for i in indices_periodo]
mediana = [lista_mediana[i] for i in indices_periodo]

# %%
fig, ax = plt.subplots(figsize=(7,7))
fig.subplots_adjust(hspace=0.5)

sns.barplot(y=mediana, x=periodos)
ax.tick_params(axis='x', rotation=30);

# %% [markdown]
# ## MEDIANA de ventas FUERA DE REINO UNIDO por periodos

# %%
from statistics import median

# separo un dataframe con ventas FUERA de reino unido
Out_kingdom = data[data['Out_kingdom'] == 1]

# creo una lista de los periodos de venta
periodos = Out_kingdom.Periodo.value_counts().reset_index(name='cantidad')
lista_periodos = periodos['index']

# funcion que calcula el promedio dependiendo de el periodo 
def calcular_mediana(lista):
    mediana_periodo = []
    
    for i in lista_periodos:
        minidf = lista[lista['Periodo'] == i]
        mediana = median(minidf.Monto)
        mediana_periodo.append(mediana)
        
    return(mediana_periodo)

lista_mediana = calcular_mediana(Out_kingdom)

# organizare el periodo en orden
indices_periodo = np.argsort(lista_periodos)
# organizo las lista en orden ascendente de los periodos
periodos = [lista_periodos[i] for i in indices_periodo]
mediana = [lista_mediana[i] for i in indices_periodo]

# %%
fig, ax = plt.subplots(figsize=(7,7))
fig.subplots_adjust(hspace=0.5)

sns.barplot(y=mediana, x=periodos)
ax.tick_params(axis='x', rotation=30);

# %% [markdown]
# ## 2) ¿Cual es el promedio de articulos cada mes?

# %%
## creare una funcion que me calcule la cantidad PROMEDIO de articulos dependiendo de la fecha
periodo_tabla = data.Periodo.value_counts().reset_index(name='fecha')
lista_periodos = periodo_tabla['index']

def calcular_promedio_productos(lista):
    
    promedio_cantidad_valor = []
    
    for i in lista_periodos:
        tabla_periodo = lista[lista['Periodo'] == i]
        promedio_cantidad = tabla_periodo.Cantidad.mean()
    
        promedio_cantidad_valor.append(promedio_cantidad)
        
    return(promedio_cantidad_valor)

lista_promedio = calcular_promedio_productos(data)

# organizare el periodo en orden
indices_periodo = np.argsort(lista_periodos)
# organizo las lista en orden ascendente de los periodos
periodos = [lista_periodos[i] for i in indices_periodo]
promedio = [lista_promedio[i] for i in indices_periodo]

# %%
fig, ax = plt.subplots( figsize=(7,7))
fig.subplots_adjust(hspace=0.5)

sns.barplot(x=periodos, y=promedio)

ax.tick_params(axis='x', rotation=30);

# %% [markdown]
# # 2.1) cual es el promedio de articulos DENTRO de reino unido

# %%
# separo un dataframe con ventas DENTRO de reino unido
Out_kingdom = data[data['Out_kingdom'] == 0]

# creo una lista de los periodos de venta
periodos = Out_kingdom.Periodo.value_counts().reset_index(name='cantidad')
lista_periodos = periodos['index']

# funcion que calcula el promedio dependiendo de el periodo 
def calcular_promedio(lista):
    promedio_cantidad = []
    
    for i in lista_periodos:
        minidf = lista[lista['Periodo'] == i]
        cantidad = minidf.Cantidad.mean()
        promedio_cantidad.append(cantidad)
        
    return(promedio_cantidad)

lista_cantidad = calcular_promedio(Out_kingdom)

# organizare el periodo en orden
indices_periodo = np.argsort(lista_periodos)
# organizo las lista en orden ascendente de los periodos
periodos = [lista_periodos[i] for i in indices_periodo]
cantidad = [lista_cantidad[i] for i in indices_periodo]

# %%
fig, ax = plt.subplots( figsize=(7,7))
fig.subplots_adjust(hspace=0.5)

sns.barplot(x=periodos, y=cantidad)
ax.set_title('calculo PROMEDIO de articulos dentro de UK')
ax.set_ylabel('cantidad de articulos')
ax.set_xlabel('periodo')
ax.tick_params(axis='x', rotation=30);

# %% [markdown]
# ## 2.2) Cual es el promdio de articulos vendidos FUERA de reino unido

# %%
# separo un dataframe con ventas FUERA de reino unido
Out_kingdom = data[data['Out_kingdom'] == 1]

# creo una lista de los periodos de venta
periodos = Out_kingdom.Periodo.value_counts().reset_index(name='cantidad')
lista_periodos = periodos['index']

# funcion que calcula el promedio dependiendo de el periodo 
def calcular_promedio(lista):
    promedio_cantidad = []
    
    for i in lista_periodos:
        minidf = lista[lista['Periodo'] == i]
        cantidad = minidf.Cantidad.mean()
        promedio_cantidad.append(cantidad)
        
    return(promedio_cantidad)

lista_cantidad = calcular_promedio(Out_kingdom)

# organizare el periodo en orden
indices_periodo = np.argsort(lista_periodos)
# organizo las lista en orden ascendente de los periodos
periodos = [lista_periodos[i] for i in indices_periodo]
cantidad = [lista_cantidad[i] for i in indices_periodo]

# %%
fig, ax = plt.subplots( figsize=(7,7))
fig.subplots_adjust(hspace=0.5)

sns.barplot(x=periodos, y=cantidad)
ax.set_title('calculo del PROMEDIO fuera de UK')
ax.set_ylabel('cantidad de articulos')
ax.tick_params(axis='x', rotation=30);

# %% [markdown]
# ## 3) cuantas ventas hubo  durante los periodos ?

# %%
## contare la cantidad de facturas emitidas en un periodo seleccionado

# lista de los periodos
lista_periodos = data['Periodo'].value_counts().reset_index(name='cantidad')
lista_periodos = lista_periodos['index']

# funcion que cuneta la cantidad de facturas emitidas en un periodo seleccionado
def cantidad_facturas(data):
    
    lista_cantidad = []
    
    for i in lista_periodos:
        mini_df = data[data['Periodo'] == i]
        cantidad_f = len(mini_df['N_factura'])
        
        lista_cantidad.append(cantidad_f)
    
    return lista_cantidad

lista_cantidad = cantidad_facturas(data)

# organizare de menos a mayor los periodos y guardare sus indices para no perder la relacion con la cantidad de
# facturas

lista_indices = np.argsort(lista_periodos)

periodos = [lista_periodos[i] for i in lista_indices]
cantidad = [lista_cantidad[i] for i in lista_indices]

# %%
fig, ax = plt.subplots(figsize=(7,7))
fig.subplots_adjust(hspace=0.5)

sns.barplot(x=periodos, y=cantidad)
ax.set_title('Total de ventas')
ax.set_ylabel('Numero de ventas')
ax.set_xlabel('Periodo')
ax.tick_params(axis='x', rotation=30);

# %% [markdown]
# ## 3.1)cantidad de ventas echas FUERA de reino unido

# %%
# separo un dataframe con ventas FUERA de reino unido
Out_kingdom = data[data['Out_kingdom'] == 1]

# creo una lista de los periodos de venta
periodos = Out_kingdom.Periodo.value_counts().reset_index(name='cantidad')
lista_periodos = periodos['index']

# funcion que calcula el promedio dependiendo de el periodo 
def cantidad_facturas(data):
    
    lista_cantidad = []
    
    for i in lista_periodos:
        mini_df = data[data['Periodo'] == i]
        cantidad_f = len(mini_df['N_factura'])
        
        lista_cantidad.append(cantidad_f)
    
    return lista_cantidad

lista_cantidad = cantidad_facturas(Out_kingdom)

# organizare el periodo en orden
indices_periodo = np.argsort(lista_periodos)
# organizo las lista en orden ascendente de los periodos
periodos = [lista_periodos[i] for i in indices_periodo]
cantidad = [lista_cantidad[i] for i in indices_periodo]

# %%
fig, ax = plt.subplots(figsize=(7,7))
fig.subplots_adjust(hspace=0.5)

sns.barplot(x=periodos, y=cantidad)
ax.set_title('Ventas fuera de UK')
ax.set_ylabel('Cantidad de ventas')
ax.set_xlabel('periodo')
ax.tick_params(axis='x', rotation=30);

# %% [markdown]
# ## 3.2) cantidad de ventas echas DENTRO de reino unido

# %%
# separo un dataframe con ventas DENTRO de reino unido
Out_kingdom = data[data['Out_kingdom'] == 0]

# creo una lista de los periodos de venta
periodos = Out_kingdom.Periodo.value_counts().reset_index(name='cantidad')
lista_periodos = periodos['index']

# funcion que calcula el promedio dependiendo de el periodo 
def cantidad_facturas(data):
    
    lista_cantidad = []
    
    for i in lista_periodos:
        mini_df = data[data['Periodo'] == i]
        cantidad_f = len(mini_df['N_factura'])
        
        lista_cantidad.append(cantidad_f)
    
    return lista_cantidad

lista_cantidad = cantidad_facturas(Out_kingdom)

# organizare el periodo en orden
indices_periodo = np.argsort(lista_periodos)
# organizo las lista en orden ascendente de los periodos
periodos = [lista_periodos[i] for i in indices_periodo]
cantidad = [lista_cantidad[i] for i in indices_periodo]

# %%
fig, ax = plt.subplots(figsize=(7,7))
fig.subplots_adjust(hspace=0.5)

sns.barplot(x=periodos, y=cantidad)
ax.set_title('Cantidad de ventas DENTRO de UK')
ax.set_ylabel('cantidad de ventas')
ax.set_xlabel('Periodos')
ax.tick_params(axis='x', rotation=30);

# %% [markdown]
# ## 4) cuanto gasta en promedio un cliente (2021)
#
# - **Valor promedio de compra (VCP).** Se refiere al valor promedio de compra que cada cliente realizan en tu negocio. Se calcula dividiendo el total ingresado durante el último año entre el número de compras realizadas para todos los clientes.

# %%
# total de ventas
tabla_2021 = data[data['Año'] > 2020]
ventas = tabla_2021['Monto']
total_ventas = sum(ventas)

# cantidad de clientes
total_compra = tabla_2021.shape[0]

vcp = total_ventas / total_compra
print(f'El promedio de compras de un cliente es de ={round(vcp,2)}')
# Out:
# El promedio de compras de un cliente es de =485.91

# %% [markdown]
# ## 5) tasa de frecuencia de compras
#
# -   Tasa de frecuencia de compra (TFC). Se refiere al número de pedidos en en el periodo escogido. Se divide el número total de compras realizadas entre el total de clientes.

# %%
## total de compras realizadas
compras_2021 = data[data['Año'] > 2020]
total_compras = compras_2021.shape[0]

## cantidad de clientes
total_clientes = compras_2021['ID_Cliente']
total_clientes = set(total_clientes)

## calcula de TFC
tfc = total_compras / len(total_clientes)

print(f'la frecuencia con la que un cliente compra es de = {round(tfc,2)} pedidos en el periodo')
# Out:
# la frecuencia con la que un cliente compra es de = 4.07 pedidos en el periodo

# %% [markdown]
# ## VALOR PROMEDIO DEL CLIENTE // COSTUMMER VALUE
#
# Ahora, multiplica el VPC por el TFC para obtener el Valor Promedio de Cliente o Customer Value (CV) = VCP x TFC

# %%
vc = vcp * tfc
print(f'el valor promedio de un cliente es de {round(vc,2)} libras')
# Out:
# el valor promedio de un cliente es de 1976.46 libras

# %% [markdown]
# ## ¿Cantidad de articulos vendidos?

# %%
fig, ax = plt.subplots(figsize=(7,7))
fig.subplots_adjust(hspace=0.5)

sns.countplot(data=data, x='Volumen_cantidad')
ax.tick_params(axis='x', rotation=30);

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.barplot(data=netherlands,y='Monto',x='Volumen_cantidad')
ax.tick_params(axis='x', rotation=30);

# %% [markdown]
# ## Observaciones
# - Aproximadamente 5000 compras son entre 100 a 200 articulos
# - Mas de 1000 compras son de 5000 articulos

# %% [markdown]
# # promedio de compra por paises

# %%
# creo una lista de los periodos de venta
paises = data.País.value_counts().reset_index(name='cantidad')
lista_paises = paises['index']

# funcion que calcula el promedio dependiendo de el periodo 
def promedio_pais(data):
    
    lista_promedio = []
    
    for i in lista_paises:
        mini_df = data[data['País'] == i]
        promedio_pais =  mini_df['Monto'].mean()
        
        lista_promedio.append(promedio_pais)
    
    return(lista_promedio)

lista_promedio = promedio_pais(data)

# %%
fig, ax = plt.subplots(figsize=(7,7))
fig.subplots_adjust(hspace=0.5)

sns.barplot(y=lista_paises, x=lista_promedio)
ax.tick_params(axis='x', rotation=1)
ax.set_title('PROMEDIO de compras por pais')
ax.set_ylabel('Promedio')
ax.set_xlabel('Promedio')
plt.show()

# %% [markdown]
# # Observaciones
# - Destacan paises como EIRE, Netherlands, Australia, Portugal, Singapur, Brazil, RSA, Lebanon, Israel, Japan entre otros que tienen un promedio de compras mayores a los de reino unido

# %% [markdown]
# ## calculo de la MEDIANA por paises

# %%
from statistics import median

#creo una lista de los paises
paises = data.País.value_counts().reset_index(name='cantidad')
lista_paises = paises['index']

def calculo_mediana(data):
    
    mediana = []
    
    for i in lista_paises:
        
        mini_d = data[data['País'] == i]
        valor=median(mini_d['Monto'])
        
        mediana.append(valor)
    
    return(mediana)
lista_medianas = calculo_mediana(data)

# %%
fig, ax = plt.subplots(figsize=(7,7))
fig.subplots_adjust(hspace=0.5)

sns.barplot(y=lista_paises, x=lista_medianas)
ax.set_title('MEDIANA de compras ')
ax.set_xlabel('Mediana')
ax.set_ylabel('Paises')
ax.tick_params(axis='x', rotation=1);

# %% [markdown]
# # Observaciones
#
# - aun destacan paises tales como Lebanon, Brazil, unid Arab Emirates, Singapore, Japan, RSA, Netherlands, israel, grecia

# %% [markdown]
# ## PORCENTAJE total de ventas dentro y fuera de reino unido

# %%
#0 = dentro del reino unido
#1 = fuera del reino unido

sectores = data['Out_kingdom'].value_counts().reset_index(name='cantidad')
sectores = sectores['index']

def porcentaje_ventas_sector(df):
    
    total_ventas = sum(df['Monto'])
    porcentaje = []
    
    for i in sectores:
        
        mini_df = df[df['Out_kingdom'] == i]
        calculo = sum((mini_df['Monto']))/total_ventas
        porcentaje.append(calculo)
    
    return porcentaje
        
porcentaje = porcentaje_ventas_sector(data)

# %%
desfase = (0.1,0)
plt.pie(porcentaje, labels=['dentro_UK','fuera_UK'], autopct="%0.1f %%", explode=desfase)
plt.axis("equal")
plt.show()

# %%
dentro_king = data[data['Out_kingdom'] == 0 ]
fuera_king = data[data['Out_kingdom'] == 1 ]
suma_fuera = sum(fuera_king['Monto'])
suma_dentro = sum(dentro_king['Monto'])

# %%
print(f'TOTAL de ventas fuera de UK = {round(suma_fuera,2)}')
print('--'*20)
print(f'TOTAL de ventas dentro de UK = {round(suma_dentro,2)}')
# Out:
# TOTAL de ventas fuera de UK = 1603016.35
# ----------------------------------------
# TOTAL de ventas dentro de UK = 7308391.55

# %% [markdown]
# # PROMEDIO de ventas dentro y fuera de reino unido

# %%
sectores = data['Out_kingdom'].value_counts().reset_index(name='cantidad')
sectores = sectores['index']

def promedio_ventas_sector(df):
    
    promedio = []
    
    for i in sectores:
        
        mini_df = df[df['Out_kingdom'] == i]
        calculo = mini_df['Monto'].mean()
        promedio.append(calculo)
    
    return promedio
        
promedio = promedio_ventas_sector(data)

# %%
desfase = (0.1,0)
plt.pie(promedio, labels=['dentro_UK','fuera_UK'], autopct="%0.1f %%", explode=desfase)
plt.axis("equal")
plt.show()

# %%
mean_fuera = (fuera_king['Monto']).mean()
mean_dentro = (dentro_king['Monto']).mean()

print(f'PROMEDIO fuera de UK = {mean_fuera}')
print('--'*20)
print(f'PROMEDIO dentro de UK = {mean_dentro}')
# Out:
# PROMEDIO fuera de UK = 848.6057967178406
# ----------------------------------------
# PROMEDIO dentro de UK = 438.33692496851387

# %%
plt.pie([mean_dentro,mean_fuera], labels=('UK','no UK'), autopct="%0.1f %%");

# %% [markdown]
# # MEDIANA de ventas dentro y fuera de reino unido

# %%
from statistics import median

sectores = data['Out_kingdom'].value_counts().reset_index(name='cantidad')
sectores = sectores['index']

def mediana_ventas_sector(df):
    
    mediana = []
    
    for i in sectores:
        
        mini_df = df[df['Out_kingdom'] == i]
        calculo = median(mini_df['Monto'])
        mediana.append(calculo)
    
    return mediana
        
mediana = mediana_ventas_sector(data)

# %%
desfase = (0.1,0)
plt.pie(mediana, labels=['dentro_UK','fuera_UK'], autopct="%0.1f %%", explode=desfase)
plt.axis("equal")
plt.show()

# %%
from statistics import median

median_fuera = (median(fuera_king['Monto']))
median_dentro = (median(dentro_king['Monto']))

print(f'mediana fuera de UK = {median_fuera}')
print('--'*20)
print(f'median dentro de UK = {median_dentro}')
# Out:
# mediana fuera de UK = 424.06
# ----------------------------------------
# median dentro de UK = 299.09

# %% [markdown]
# # Porcentaje de facturas de los diferentes paises

# %%
data_paises = data['País'].value_counts().reset_index(name='cantidad')
lista_paises = data_paises['index']

def porcentaje_facturas(df):
    
    porcentajes = []
    total_facturas = len(df['N_factura'])
    
    for i in lista_paises:
        mini_df = df[df['País'] == i]
        valor_porcentaje = len(mini_df['N_factura'])/total_facturas
        
        porcentajes.append(valor_porcentaje)
        
    return porcentajes

porcentaje = porcentaje_facturas(data)

# %%
fig, ax = plt.subplots(figsize=(7,7))

sns.barplot(x=porcentaje,y=lista_paises)
# Out:
# <AxesSubplot:ylabel='index'>

# %% [markdown]
# # OBSERVACIONES
# - Cuando veo el procentaje de facturas de los paises veo que los mas representativos son UK Germany France  y EIRE dandome a entender que estos paises son los que mas compras hacen
# - la mediana de los paises # Lebanon, Brazil, unid Arab Emirates, Singapore, Japan, RSA, Netherlands, israel, grecia es superiror a la mediana y el promedio de venta en UK esto me podria indicar que estos paises hacen compras extremadamente grandes la pregunta es que tan frecuentemente lo hacen

# %% [markdown]
# # coeficiente de correlacion

# %%
data.corr()
# Out:
#              Unnamed: 0  N_factura  ID_Cliente  Cantidad     Monto       Dia  \
# Unnamed: 0     1.000000  -0.016124    0.002839  0.005396  0.006336  0.011551
# N_factura     -0.016124   1.000000   -0.009425  0.012851  0.014817  0.093686
# ID_Cliente     0.002839  -0.009425    1.000000 -0.019747 -0.011392 -0.009154
# Cantidad       0.005396   0.012851   -0.019747  1.000000  0.906516 -0.001103
# Monto          0.006336   0.014817   -0.011392  0.906516  1.000000 -0.004459
# Dia            0.011551   0.093686   -0.009154 -0.001103 -0.004459  1.000000
# Año           -0.011620   0.470914   -0.031706  0.016333  0.012150  0.176355
# Out_kingdom   -0.002398   0.013707   -0.413391  0.070713  0.073978  0.014728
#
#                   Año  Out_kingdom
# Unnamed: 0  -0.011620    -0.002398
# N_factura    0.470914     0.013707
# ID_Cliente  -0.031706    -0.413391
# Cantidad     0.016333     0.070713
# Monto        0.012150     0.073978
# Dia          0.176355     0.014728
# Año          1.000000     0.022648
# Out_kingdom  0.022648     1.000000

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.stripplot(data=data, x='Monto', y='País', hue='Volumen_cantidad')
# Out:
# <AxesSubplot:xlabel='Monto', ylabel='País'>

# %%
data.head()
# Out:
#    Unnamed: 0  N_factura  ID_Cliente            País  Cantidad   Monto  \
# 0           0     548370     15528.0  United Kingdom       123  229.33
# 1           1     575767     17348.0  United Kingdom       163  209.73
# 2           3     549106     17045.0  United Kingdom         1   39.95
# 3           4     573112     16416.0  United Kingdom       357  344.83
# 4           5     576630     13816.0         Germany        91  199.98
#
#                  Fecha Continente        Mes  Dia   Año  Periodo  Out_kingdom  \
# 0  2021-03-30 16:14:00     Europa      Marzo   30  2021  2021 03            0
# 1  2021-11-11 11:11:00     Europa  Noviembre   11  2021  2021 11            0
# 2  2021-04-06 12:08:00     Europa      Abril    6  2021  2021 04            0
# 3  2021-10-27 15:33:00     Europa    Octubre   27  2021  2021 10            0
# 4  2021-11-16 08:38:00     Europa  Noviembre   16  2021  2021 11            1
#
#   Volumen_cantidad
# 0      100<=x<=300
# 1      100<=x<=300
# 2            x<100
# 3      300<=x<=600
# 4            x<100

# %%
fig, ax = plt.subplots(figsize=(7,7))
sns.scatterplot(data=data, x='Cantidad', y='País', hue='Volumen_cantidad',alpha=0.1)
sns.color_palette("husl", 9);

# %%
fig, ax = plt.subplots(figsize=(7,7))
sns.scatterplot(data=data, x='N_factura', y='País', hue='Volumen_cantidad')
# Out:
# <AxesSubplot:xlabel='N_factura', ylabel='País'>

# %% [markdown]
# # Relacion entre la cantidad y el monto de la compra

# %%
sns.lmplot(data=data,x='Monto', y='Cantidad')

# %% [markdown]
# ## Observaciones
# se aprecia que hay una correalacion positiva entre la cntidad y el precio, si aumenta una la otra aumenta de igual manera

# %%
periodo_2021_11 = data[data['Periodo'] == '2021 11']

# %%
paises_11 = periodo_2021_11['País'].value_counts()

fig, ax = plt.subplots(figsize=(10,10))
sns.stripplot(data=periodo_2021_11, x='Monto', y='País', hue='Volumen_cantidad')
# Out:
# <AxesSubplot:xlabel='Monto', ylabel='País'>

# %% [markdown]
# # Observaciones
# tengo una lista de paises que en su momento han echo compras de mas de 3000 articulos siendo los mas frecuentes

# %%
paises_3000 = data[data['Volumen_cantidad'] == 'X > 3000']
lista_paises_3000 =paises_3000['País'].value_counts()
lista_paises_3000 = lista_paises_3000.reset_index(name='cantidad')
lista_paises_3000[0:4]
# Out:
#             index  cantidad
# 0  United Kingdom       181
# 1     Netherlands        23
# 2       Australia         8
# 3            EIRE         6

# %% [markdown]
# ## ¿Que paso en diciembre y noviembre del año 2021?

# %% [markdown]
# # Observacion
# - aunque en noviembre se han echo mas ventas que en diciembre se puede apreciar que se facturo mas en diciembre que en noviembre esto quizas pueda ser aque la pocas ventas que se hicieron fuero de una gran cantidad de articulos

# %%
df_100_300 = data[data['Volumen_cantidad'] == '100<=x<=300']

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.countplot(data=df_100_300, x='Periodo')
ax.tick_params(axis='x', rotation=30);

# %%
df_3000 = data[data['Volumen_cantidad'] == 'X > 3000']

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.countplot(data=df_3000, x='Periodo')
ax.tick_params(axis='x', rotation=30);

# %%
df_300_x_600 = data[data['Volumen_cantidad'] == '300<=x<=600']

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.countplot(data=df_300_x_600, x='Periodo')
ax.tick_params(axis='x', rotation=30);

# %%
vol_cant = data['Volumen_cantidad'].value_counts().reset_index(name='cantidad')
vol_cant
# Out:
#            index  cantidad
# 0    100<=x<=300      7783
# 1          x<100      6232
# 2    300<=x<=600      3034
# 3    600<=x<=900       666
# 4  1000<=x<=3000       499
# 5       X > 3000       234
# 6   900<=x<=1000       114

# %%
df_600_x_900 = data[data['Volumen_cantidad'] == '600<=x<=900']
fig, ax = plt.subplots(figsize=(10,10))
sns.countplot(data=df_600_x_900, x='Periodo')
ax.tick_params(axis='x', rotation=30);

# %%
df_900_x_1000 = data[data['Volumen_cantidad'] == '900<=x<=1000']
fig, ax = plt.subplots(figsize=(10,10))
sns.countplot(data=df_900_x_1000, x='Periodo')
ax.tick_params(axis='x', rotation=30);

# %%
df_1000_x_3000 = data[data['Volumen_cantidad'] == '1000<=x<=3000']
fig, ax = plt.subplots(figsize=(10,10))
sns.countplot(data=df_1000_x_3000, x='Periodo')
ax.tick_params(axis='x', rotation=30);
